# %%
nama = "BENEDIKTUS"
ttl = "SINGKAWANG, 11-07-2002"
kelamin = "LAKI-LAKI"
goldarah = "B"
alamat = "JL. GN BAWANG NO.46"
rtrw = "031/013"
keldesa = "PASIRAN"
kecamatan = "SINGKAWANG BARAT"
agama = "KHATOLIK"
perkawinan = "Belum Kawin"
status = "PELAJAR/MAHASISWA"
kewarganegaraan = "WNI"
berlaku = "SEUMUR HIDUP"
tglktp = "05-03-2020"
jenissim = 'C'
alamatlengkap = """JL. GN BAWANG NO.46
SINGKAWANG BARAT
KOTA SINGKAWANG"""
tempat = "KALBAR"
batassim = "14-07-2025"
alamatsekarang = """JL. GN BAWANG NO.46
                        SINGKAWANG BARAT
                        KOTA SINGKAWANG"""
sd= "SDN 24 Singkawang, Kec. Singkawang Barat, Prov. Kalimantan Barat"
smp= "SMPN 07 Singkawang, Kec. Singkawang Selatan, Prov. Kalimantan Barat"
smu= "SMK Tsjafioeddin Singkawang, Kec. Singkawang Barat, Prov. Kalimantan Barat"
kuliah= "STMIK Pontianak, Kec. Pontianak Kota, Prov. Kalimantan Barat"
nonformal1= "-"
organisasi1 = "-"
pengalamankerja1 = "-"
prestasi1 = "-"

print("Nama : Benediktus")
print("NIM  : 202102240")
menu = int
while (menu != 0) :
    # Main Menu
    pilihmenu = """    
=============================Menu Utama=============================
1. Kartu Tanda Penduduk (KTP)
2. Surat Izin Mengemudi (SIM)
3. Curriculume Vitae (CV)
0. Keluar
Inputkan angka untuk memilih menu yang ingin ditampilkan: """
    menu = int(input(pilihmenu))

    if (menu == 1) :
        # KTP
        print("")
        print("========================Kartu Tanda Penduduk========================")
        print("")
        print("")
        print(" NIK     : xxxxxxxxxxxxxxx")
        print("")
        print(" Nama                  : ", nama)
        print(" Tempat/Tgl Lahir      : ", ttl)
        print(" Jenis Kelamin         : ", kelamin, "       Gol. Darah  :", goldarah)
        print(" Alamat                : ", alamat)
        print("      RT/RW            : ", rtrw)
        print("      Kel/Desa         : ", keldesa)
        print("      Kecamatan        : ", kecamatan)
        print(" Agama                 : ", agama)
        print(" Status Perkawinan     : ", perkawinan)
        print(" Pekerjaan             : ", status)
        print(" Kewarganegaraan       : ", kewarganegaraan)
        print(" Berlaku Hingga        : ", berlaku)
        print("")
        print("                                       Tanggal Pembuatan:", tglktp)
        print("====================================================================")
    
    elif (menu == 2):
        # SIM
        print("")
        print("========================Surat Izin Mengemudi========================")
        print("                                 ", jenissim)
        print("")
        print("1. ", nama)
        print("2. ", ttl)
        print("3. ", goldarah, " - ", kelamin)
        print("4. ", alamatlengkap)
        print("5. ", status)
        print("6. ", tempat)
        print("                                         Berlaku sampai: ", batassim)
        print("====================================================================")
        
    elif (menu == 3) :
        print("")
        print("==========================Curriculume Vitae=========================")
        print("")
        print("")
        print("Nama                 : ", nama)
        print("Tempat Tanggal Lahir : ", ttl)
        print("Jenis Kelamin        : ", kelamin)
        print("Agama                : ", agama)
        print("Kewarganegaraan      : ", kewarganegaraan)
        print("Status Perkawinan    : ", perkawinan)
        print("Alamat Sekarang      : ", alamatsekarang)
        print("")
        print("----Pendidikan-------------------------------------------------")
        print("FORMAL:")
        print("* ", sd)
        print("* ", smp)
        print("* ", smu)
        print("* ", kuliah)
        print("")
        print("NON FORMAL:")
        print("* ", nonformal1)
        print("")
        print("----Organisasi/Ekstra Kurikuler--------------------------------")
        print("* ", organisasi1)
        print("")
        print("----Pengalaman Kerja-------------------------------------------")
        print("* ", pengalamankerja1)
        print("")
        print("----Prestasi/Penghargaan-------------------------------------------")
        print("* ", prestasi1)
        print("====================================================================")
# Out:
# Nama : Benediktus
# NIM  : 202102240
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-65cbaf92e191> in <module>
#      43 0. Keluar
#      44 Inputkan angka untuk memilih menu yang ingin ditampilkan: """
# ---> 45     menu = int(input(pilihmenu))
#      46
#      47     if (menu == 1) :
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
# ...
